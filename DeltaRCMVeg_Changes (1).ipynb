# %%
#import DeltaRCM_veg_2
import DeltaRCM_veg_2_Edits as dlt
#from DeltaRCM_veg_2_ORIG import L
#from DeltaRCM_veg_2_ORIG import W
#from DeltaRCM_veg_2_ORIG impo
#rt totaltimestep
#from DeltaRCM_veg_2_ORIG import Np_sed
#from DeltaRCM_veg_2_ORIG import Np_water

# %%
#commonly changed inputs        
params = {
    'f_bedload':  0.25, #% of sand,
    'totaltimestep' : 1000,
    'L': 10,  #domain size (# of cells in x-direction); typically on order of 100
    'W' : 20, #domain size (# of cells in y-direction); W = 2L for semicircle growth
    'plotinterval': 10, 
    'plotintervalstrat': 250, #record strata less frequently
    'runID':1,
    'itermax': 1, # # of interations of water routing
    'Np_water': 100, # number of water parcels; typically 2000
    'Np_sed': 100, # number of sediment parcels
    'veg': 1 #veg on or off
    #operations used in the model
}
#create an instance of the class
deltarcm = dlt.DeltaRCM(params)
###calling the setup function
deltarcm.setup()

###changing parameters
deltarcm.d_stem=10 #stem diameter

deltarcm.run()
# Out:
# t = 1
# np = 100
# np_sand = 25
# np_mud = 75
# t = 2
# np = 100
# np_sand = 25
# np_mud = 75
# t = 3
# np = 100
# np_sand = 25
# np_mud = 75
# t = 4
# np = 100
# np_sand = 25
# np_mud = 75
# t = 5
# np = 100
# np_sand = 25
# np_mud = 75
# t = 6
# np = 100
# np_sand = 25
# np_mud = 75
# t = 7
# np = 100
# np_sand = 25
# np_mud = 75
# t = 8
# np = 100
# np_sand = 25
# np_mud = 75
# t = 9
# np = 100
# np_sand = 25
# np_mud = 75
# t = 10
# np = 100
# np_sand = 25
# np_mud = 75
# t = 11
# np = 100
# np_sand = 25
# np_mud = 75
# t = 12
# np = 100
# np_sand = 25
# np_mud = 75
# t = 13
# np = 100
# np_sand = 25
# np_mud = 75
# t = 14
# np = 100
# np_sand = 25
# np_mud = 75
# t = 15
# np = 100
# np_sand = 25
# np_mud = 75
# t = 16
# np = 100
# np_sand = 25
# np_mud = 75
# t = 17
# np = 100
# np_sand = 25
# np_mud = 75
# t = 18
# np = 100
# np_sand = 25
# np_mud = 75
# t = 19
# np = 100
# np_sand = 25
# np_mud = 75
# t = 20
# np = 100
# np_sand = 25
# np_mud = 75
# t = 21
# np = 100
# ...

# %%
#create an instance of the class
deltarcm = dlt.DeltaRCM(params)
###calling the setup function
deltarcm.setup()

# %%
print(deltarcm)
